# %%
import random
import os
import matplotlib.pylab as plt
from glob import glob
import numpy as np
import webcolors
from PIL import Image
import cv2
# %matplotlib inline

from pylab import rcParams
rcParams['figure.figsize'] = 15, 30

# %%
name = '2018-12-10-102'
name = '2018-12-10-4'
name = '2018-11-30-85'
# name = '2018-12-04-123'

path = '/home/kenny/Desktop/lanes-segmentation/data/images/innopolis/' + name + '.png'

#[...,::-1]
img = cv2.imread(path, 0)
plt.imshow(img, cmap='gray')

# %%
hist = cv2.calcHist([img], [0], mask = None, histSize = [256], ranges = [0,256])

# %%
plt.hist(hist)
# Out:
# (array([184.,  71.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   1.]),
#  array([4.0000e+00, 3.8560e+03, 7.7080e+03, 1.1560e+04, 1.5412e+04,
#         1.9264e+04, 2.3116e+04, 2.6968e+04, 3.0820e+04, 3.4672e+04,
#         3.8524e+04], dtype=float32),
#  <a list of 10 Patch objects>)

# %%
def vis(aug, image=image):
    augmented = aug(image=image)

    image_augmented = augmented['image']

    f, ax = plt.subplots(2, 1, figsize=(15, 15))

    ax[0].imshow(image)
    ax[1].imshow(image_augmented)

# %%
from albumentations import (
    OneOf,
    Blur,
    RandomGamma,
    HueSaturationValue,
    RGBShift,
    RandomBrightness,
    RandomContrast,
    MedianBlur,
    CLAHE
)

# %%
# BLUR
aug = Blur(blur_limit=5, p=1.)
vis(aug)

# %%
# Random Gamma
aug = RandomGamma(gamma_limit=(50, 150), p=1.)
vis(aug)

# %%
# HSV SHIFT (prob 0.25)
aug = HueSaturationValue(hue_shift_limit=20, sat_shift_limit=30, val_shift_limit=20, p=1.)
vis(aug)

# %%
# RGB SHIFT
aug = RGBShift(r_shift_limit=15, g_shift_limit=5, b_shift_limit=15, p=1.)
vis(aug)

# %%
# Random Brightness
aug = RandomBrightness(limit=.25, p=1.)
vis(aug)

# %%
# Random Contrast (prob 0.25)
aug = RandomContrast(limit=.25, p=1.)
vis(aug)

# %%
# Median Blur
aug = MedianBlur(blur_limit=5, p=1.)
vis(aug)

# %%
# Contrast Limited Adaptive Histogram Equalization
aug = CLAHE(clip_limit=2.0, tile_grid_size=(8, 8), p=1.)
vis(aug)
