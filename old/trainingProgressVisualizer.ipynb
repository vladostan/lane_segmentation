# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('logs/innopolis/2019-01-10 16-36-37.log')
data.head()
# Out:
#    epoch       acc      loss      lr   val_acc  val_loss
# 0      0  0.767459  0.507845  0.0001  0.781468  0.442886
# 1      1  0.782853  0.411167  0.0001  0.814294  0.446732
# 2      2  0.831870  0.379639  0.0001  0.820441  0.380987
# 3      3  0.835462  0.367559  0.0001  0.837349  0.357065
# 4      4  0.838884  0.361776  0.0001  0.842222  0.347773

# %%
data[['acc','loss','val_acc', 'val_loss']].head()
# Out:
#         acc      loss   val_acc  val_loss
# 0  0.767459  0.507845  0.781468  0.442886
# 1  0.782853  0.411167  0.814294  0.446732
# 2  0.831870  0.379639  0.820441  0.380987
# 3  0.835462  0.367559  0.837349  0.357065
# 4  0.838884  0.361776  0.842222  0.347773

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15,10)
sns.lineplot(ax=ax, data = data[['acc','loss','val_acc', 'val_loss']], linewidth=2.5)
ax.set_xlabel('Epoch')
ax.set_title('Training progress')
# fig.savefig('results/final/training_progress.png')
# Out:
# Text(0.5, 1.0, 'Training progress')
